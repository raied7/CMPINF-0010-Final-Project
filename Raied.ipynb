# %%
# load pandas 
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 22})

# load the tree data directly from the WPRDC and parse directly
trees = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da",
                           index_col="id") 

# Get all the neighborhoods where the data was collected
nhoods = trees["neighborhood"].unique()

# Get all the different types of trees 
type_trees = trees["common_name"].unique()

print("There are " + str(len(nhoods)) + " neighborhoods in Pittsburgh")
print("There are " + str(len(type_trees)) + " different types of tress all over Pittsburgh")

print("The top 5 neighborhoods with the most trees are:")

trees["neighborhood"].value_counts().head(5)
# Out:
# There are 91 neighborhoods in Pittsburgh
# There are 235 different types of tress all over Pittsburgh
# The top 5 neighborhoods with the most trees are:
# Squirrel Hill South    5073
# Highland Park          2941
# Squirrel Hill North    2083
# South Side Flats       1693
# Shadyside              1558
# Name: neighborhood, dtype: int64

# %%
# Bar graph of types of trees in each neighborhood
df2 = pd.DataFrame(dictionary.values(), columns=type_trees,index=nhoods)

# Plot a bar chart
df2.plot.bar(stacked=True, figsize=(25,25))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/cmpinf0010/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1675                     make_block(
# -> 1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#    1677                     )
#
# ~/opt/anaconda3/envs/cmpinf0010/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2731
# -> 2732     return klass(values, ndim=ndim, placement=placement)
#    2733
#
# ~/opt/anaconda3/envs/cmpinf0010/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     142             raise ValueError(
# --> 143                 f"Wrong number of items passed {len(self.values)}, "
# ...

# %%
# Pie chart of different types of trees in Pittsburgh
trees["common_name"].value_counts().plot.pie(y='common_name', subplots=False, figsize=(50,50))
# Out:
# <AxesSubplot:ylabel='common_name'>
